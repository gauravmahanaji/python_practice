# %%
# comments is not readable with python compiler

# %%
print("hello") # this is my  first python program
# Out:
# hello

# %%
print("how are you mommy ")  # this is my second print statement
# Out:
# how are you mommy

# %%
a = 5
b = 7
print( a + b)
# Out:
# 12

# %%
# FORMAT FUNCTION

# %%
name = "gaurav"
age  = 30
height = "5 feet 9 inch"
print(""" my name is {2} 
 my age is {1} 
 my height is {0} """ .format(name , age , height))
# Out:
#  my name is 5 feet 9 inch
#  my age is 30
#  my height is gaurav

# %%
SECOND TYPE OF METHOD FUNCTION

# %%
print(""" i am learning {} 
          and i have learned {} 
          and i have learned {} 
          """.format("python","git and github", "software engnerering"))
# Out:
#  i am learning python
#           and i have learned git and github
#           and i have learned software engnerering

# %%
print(""" i am learning {2} 
          and i have learned {1} 
          and i have learned {0} 
          """.format("python","git and github", "software engnerering"))
# Out:
#  i am learning software engnerering
#           and i have learned git and github
#           and i have learned python

# %%
# format() vs f-string (Modern Python)

# %%
name = "gaurav" 
age = 20
print(f"my name is {name} and my age {age}")
# Out:
# my name is gaurav and my age 20

# %%
name = " jyoti"
work = "house wife"
print(f"my name is {name } and my work is {work}")
# Out:
# my name is  jyoti and my work is house wife

# %%
print(" today is sunday")
# Out:
#  today is sunday

# %%
ESCAPE SEQUENCE

# %%
print('hello i didn\'t know\' about him earlier ')
# Out:
# hello i didn't know' about him earlier

# %%
print(' sorry i didn\'t know about him earlier ')
# Out:
#  sorry i didn't know about him earlier

# %%
print(' i didn\'t want to spend time with you ')
# Out:
#  i didn't want to spend time with you

# %%
print('he didn\'t want to go to school with you he didn\'t want to come with you')
# Out:
# he didn't want to go to school with you he didn't want to come with you

# %%
print("today is monday")
# Out:
# today is monday
